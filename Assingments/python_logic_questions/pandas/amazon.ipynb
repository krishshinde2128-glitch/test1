# %%
import pandas as pd

# %%
laptop_data = pd.read_csv("./amazon_cameras.csv")
print(laptop_data.head())
# Out:
#                                              product   price  rating  \
# 0  (Renewed) HP ProBook 640 G1 14-inch Laptop (Co...  28,999     5.0
# 1  (Renewed) Hitachi Flora Laptop SE210 AMD E1-21...  16,990     1.0
# 2  Mi Notebook Horizon Edition 14 Intel Core i7-1...  59,990     4.2
# 3  Lenovo IdeaPad Slim 3 2021 Intel Core i3 11th ...  45,990     4.3
# 4  HP Chromebook x360 14-inch (35.56 cms) Thin & ...  31,990     3.8
#
#    rating_count                                                url
# 0             1  https://www.amazon.in//HP-640-Upgradable-Graph...
# 1             1  https://www.amazon.in//Hitachi-Processor-Ultra...
# 2           845  https://www.amazon.in//Notebook-Horizon-i7-105...
# 3            46  https://www.amazon.in//gp/slredirect/picassoRe...
# 4             9  https://www.amazon.in//HP-Chromebook-14-inch-T...

# %%
print(laptop_data.head())
# Out:
#                                              product   price  rating  \
# 0  (Renewed) HP ProBook 640 G1 14-inch Laptop (Co...  28,999     5.0
# 1  (Renewed) Hitachi Flora Laptop SE210 AMD E1-21...  16,990     1.0
# 2  Mi Notebook Horizon Edition 14 Intel Core i7-1...  59,990     4.2
# 3  Lenovo IdeaPad Slim 3 2021 Intel Core i3 11th ...  45,990     4.3
# 4  HP Chromebook x360 14-inch (35.56 cms) Thin & ...  31,990     3.8
#
#    rating_count                                                url
# 0             1  https://www.amazon.in//HP-640-Upgradable-Graph...
# 1             1  https://www.amazon.in//Hitachi-Processor-Ultra...
# 2           845  https://www.amazon.in//Notebook-Horizon-i7-105...
# 3            46  https://www.amazon.in//gp/slredirect/picassoRe...
# 4             9  https://www.amazon.in//HP-Chromebook-14-inch-T...

# %%
print(laptop_data.tail())
# Out:
#                                                product   price  rating  \
# 351  Lenovo IdeaPad Slim 3 2021 Intel Core i3 11th ...  45,990     4.3
# 352  MSI Bravo 15 Ryzen 7 4800H 15.6" (39.62cms) FH...  74,990     4.3
# 353  Dell Vostro 3400 14 inch (35.5 cm) FHD Display...  43,726     3.8
# 354  Lenovo IdeaPad Slim 3 2021 Intel Core i5 11th ...  59,990     4.2
# 355  Lenovo IdeaPad Slim 3 2021 11th Gen Intel Core...  60,490     4.1
#
#      rating_count                                                url
# 351            46  https://www.amazon.in//gp/slredirect/picassoRe...
# 352           109  https://www.amazon.in//gp/slredirect/picassoRe...
# 353           304  https://www.amazon.in//gp/slredirect/picassoRe...
# 354            39  https://www.amazon.in//gp/slredirect/picassoRe...
# 355            85  https://www.amazon.in//gp/slredirect/picassoRe...

# %%
print(pd.to_numeric(laptop_data["price"].astype(str).str.replace(",", "", regex=False), errors="coerce"))
# Out:
# 0      28999
# 1      16990
# 2      59990
# 3      45990
# 4      31990
#        ...
# 351    45990
# 352    74990
# 353    43726
# 354    59990
# 355    60490
# Name: price, Length: 356, dtype: int64

# %%
import numpy as np
sales_data = pd.DataFrame({
    "product": ["A", "B", "C", "D"],
    "sales": ["100", "100", "100","100"]
})
# fill missing numbers using fillina()
print(sales_data["sales"].fillna(0))
# Out:
# 0    100
# 1    100
# 2    100
# 3    100
# Name: sales, dtype: object

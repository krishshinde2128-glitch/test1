# %%
import numpy as np

# %%
sensor_reading = np.array ([1,2,np.nan,4,5,np.nan])
isnan = np.isnan(sensor_reading).sum()
print(isnan)
# Out:
# 2

# %%
np.where(np.isnan(sensor_reading), np.nanmean(sensor_reading), sensor_reading)
# Out:
# array([1., 2., 3., 4., 5., 3.])

# %%
flitered = np.isnan(sensor_reading)
filtered = sensor_reading[~flitered]
print (flitered)
# Out:
# [False False  True False False  True]

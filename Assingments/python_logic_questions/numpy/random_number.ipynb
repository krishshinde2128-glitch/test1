# %%
import numpy as np
import random

# %%
age = np.random.normal(10,35,15)
print(age)
# Out:
# [ 71.85261986 -20.22922427  28.62797139 135.04977462 -49.82653863
#   40.09873641  29.21173621 -46.00036142 -18.0262474   49.36533435
#   -2.43000955  58.67159644   8.18260476  19.62944769  -1.22031716]

# %%
purchase_amount = np.random.uniform(18,35,15)
print(purchase_amount)
# Out:
# [24.45301909 27.97980484 30.62837774 23.31600227 26.73502748 34.92891055
#  29.08375234 20.82741627 25.26119892 34.33727013 19.72700475 30.92056878
#  21.4305598  19.19072793 30.88272691]

# %%
sample = np.random.choice(age, 10 , 5)
print(sample)
# Out:
# [-49.82653863  49.36533435  -2.43000955  19.62944769  29.21173621
#   40.09873641 -46.00036142  49.36533435 135.04977462  19.62944769]

# %%
dice = np.random.randint(1,7,1000)
outcome_counts = np.bincount(dice)[1:]
print (outcome_counts)
print("----------------------------------------------------------------------------")
print( dice )
# Out:
# [152 177 162 165 164 180]
# ----------------------------------------------------------------------------
# [6 3 1 2 1 1 3 4 4 3 5 4 3 2 3 2 2 3 3 2 5 6 1 2 6 5 5 5 2 2 6 1 5 2 5 3 4
#  5 6 3 3 1 3 3 6 4 5 2 2 6 1 6 2 2 5 3 2 3 5 4 2 4 2 6 2 3 5 6 6 6 5 1 6 4
#  4 1 5 6 4 3 2 4 6 3 4 4 6 4 3 5 5 2 4 2 5 5 5 1 3 3 5 2 6 6 1 4 1 6 4 5 5
#  6 2 1 2 3 2 6 3 4 1 2 6 4 2 4 2 1 2 6 6 1 2 1 2 2 2 2 4 4 2 5 6 5 4 5 2 3
#  1 6 4 4 6 1 6 3 5 5 3 5 3 3 4 3 5 3 3 2 2 3 2 6 4 4 6 2 3 4 5 5 6 3 5 6 1
#  2 1 4 5 4 3 4 5 2 5 1 3 2 3 6 6 1 4 6 1 6 5 3 1 5 1 4 1 1 3 2 3 6 3 3 3 5
#  6 6 6 2 4 3 2 4 3 6 2 2 1 5 1 2 5 6 3 1 4 1 5 6 2 1 3 4 3 6 3 2 4 5 2 3 2
#  3 5 2 5 1 3 1 2 1 5 5 2 5 1 1 2 1 6 4 4 5 2 3 5 1 6 3 1 3 6 3 1 4 1 1 2 1
#  1 1 5 3 6 6 2 2 6 1 4 6 5 4 1 2 5 2 6 6 1 1 5 2 1 1 2 4 1 3 4 3 1 1 5 6 1
#  4 6 4 6 3 2 3 4 6 4 5 2 4 3 4 1 2 6 3 3 2 1 5 5 2 2 2 4 1 5 4 5 4 6 4 1 4
#  1 3 2 5 2 4 1 6 2 3 4 3 6 6 5 6 4 1 5 1 6 3 3 1 1 4 2 4 1 5 6 1 4 1 4 3 4
# ...
